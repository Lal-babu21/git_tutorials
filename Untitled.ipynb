# %%
text = "programming"
print("gram" in text)
# Out:
# True

# %%
i=1
even=0
odd=0
while i<=100:
    if i%2!=0:
        odd+=1
        i+=1
        continue
    else:
        even+=1
        i+=1
print("number of even numbers upto 100 is",even)
print("number of odd numbers upto 100 is",even)
# Out:
# number of even numbers upto 100 is 50
# number of odd numbers upto 100 is 50
